# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('Womens Clothing Reviews Data.xlsx',sheet_name='Woman Clothing Reviews')

# %%
#Performing exploratory analysis on the data to understand the patterns

# %%
print(df.info() )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Product ID      23486 non-null  int64
#  1   Category        23472 non-null  object
#  2   Subcategory1    23472 non-null  object
#  3   SubCategory2    23472 non-null  object
#  4   Location        23486 non-null  object
#  5   Channel         23486 non-null  object
#  6   Customer Age    23486 non-null  int64
#  7   Review Title    19676 non-null  object
#  8   Review Text     22641 non-null  object
#  9   Rating          23486 non-null  int64
#  10  Recommend Flag  23486 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 2.0+ MB
# None

# %%
print(df.describe())
# Out:
#          Product ID  Customer Age        Rating  Recommend Flag
# count  23486.000000  23486.000000  23486.000000    23486.000000
# mean     918.118709     43.198544      4.196032        0.822362
# std      203.298980     12.279544      1.110031        0.382216
# min        0.000000     18.000000      1.000000        0.000000
# 25%      861.000000     34.000000      4.000000        1.000000
# 50%      936.000000     41.000000      5.000000        1.000000
# 75%     1078.000000     52.000000      5.000000        1.000000
# max     1205.000000     99.000000      5.000000        1.000000

# %%
df.describe(include='object')
# Out:
#        Category Subcategory1 SubCategory2 Location Channel Review Title  \
# count     23472        23472        23472    23486   23486        19676
# unique        3            6           20        4       2        13993
# top     General         Tops      Dresses  Gurgaon     Web     Love it!
# freq      13850        10468         6319     8821   13583          136
#
#                                               Review Text
# count                                               22641
# unique                                              22634
# top     Perfect fit and i've gotten so many compliment...
# freq                                                    3

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df.isna().sum()
# Out:
# Product_ID           0
# Category            14
# Subcategory1        14
# SubCategory2        14
# Location             0
# Channel              0
# Customer_Age         0
# Review_Title      3810
# Review_Text        845
# Rating               0
# Recommend_Flag       0
# dtype: int64

# %%
df=df.dropna()

# %%
df.hist()  # Plot histograms of numerical columns
plt.show()

# %%
df
# Out:
#        Product_ID        Category Subcategory1 SubCategory2   Location  \
# 2            1077         General      Dresses      Dresses    Gurgaon
# 3            1049  General Petite      Bottoms        Pants    Chennai
# 4             847         General         Tops      Blouses  Bangalore
# 5            1080         General      Dresses      Dresses    Gurgaon
# 6             858  General Petite         Tops        Knits    Gurgaon
# ...           ...             ...          ...          ...        ...
# 23481        1104  General Petite      Dresses      Dresses    Gurgaon
# 23482         862  General Petite         Tops        Knits    Gurgaon
# 23483        1104  General Petite      Dresses      Dresses    Gurgaon
# 23484        1084         General      Dresses      Dresses    Gurgaon
# 23485        1104  General Petite      Dresses      Dresses    Chennai
#
#       Channel  Customer_Age  \
# 2      Mobile            60
# 3         Web            50
# ...

# %%
plt.scatter(df['Subcategory1'],df['SubCategory2'])
plt.xlabel('Column 1')
plt.ylabel('Column 2')
plt.title('Relationship between Column 1 and Column 2')
plt.show()

# %%
corr_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# Countplot of a categorical column
sns.countplot(y='SubCategory2', data=df)
plt.title('Countplot of Category Column')
plt.show()

# %%
sns.countplot(x='Subcategory1', data=df)
plt.title('Countplot of Category Column')
plt.show()

# %%
cross_tab = pd.crosstab(df['SubCategory2'],df['Subcategory1'])
cross_tab
# Out:
# Subcategory1    Bottoms  Dresses  Intimate  Jackets  Tops  Trend
# SubCategory2
# Blouses               0        0         0        0  2587      0
# Casual bottoms        1        0         0        0     0      0
# Chemises              0        0         1        0     0      0
# Dresses               0     5371         0        0     0      0
# Fine gauge            0        0         0        0   927      0
# Intimates             0        0       120        0     0      0
# Jackets               0        0         0      598     0      0
# Jeans               970        0         0        0     0      0
# Knits                 0        0         0        0  3981      0
# Layering              0        0       115        0     0      0
# Legwear               0        0       131        0     0      0
# Lounge                0        0       574        0     0      0
# Outerwear             0        0         0      281     0      0
# ...

# %%
#Perform text mining tasks to understand what most frequent words are using for positive
#sentiment and negative sentiment. Create word clouds for the positive & negative reviews
#separately.

# %%
#pip install nltk wordcloud
#!pip install nltk

# %%
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud

# %%
stopwords = nltk.corpus.stopwords.words('english')
print(stopwords[:10])
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      83                 try:
# ---> 84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
#
# ~\anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
# ...

# %%
import nltk
import sklearn

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Shubham
# [nltk_data]     Jadhav\anaconda3\Lib\New folder...
# [nltk_data] Error downloading 'punkt' from
# [nltk_data]     <https://raw.githubusercontent.com/nltk/nltk_data/gh-
# [nltk_data]     pages/packages/tokenizers/punkt.zip>:   <urlopen error
# [nltk_data]     [WinError 10060] A connection attempt failed because
# [nltk_data]     the connected party did not properly respond after a
# [nltk_data]     period of time, or established connection failed
# [nltk_data]     because connected host has failed to respond>
# False

# %%
pip uninstall nltk

# %%
positive_reviews = [...]  # List of positive reviews
negative_reviews = [...]  # List of negative reviews

# Tokenize positive reviews
positive_tokens = []
for review in positive_reviews:
    tokens = nltk.word_tokenize(review.lower())
    positive_tokens.extend(tokens)

# Tokenize negative reviews
negative_tokens = []
for review in negative_reviews:
    tokens = nltk.word_tokenize(review.lower())
    negative_tokens.extend(tokens)

# Remove stopwords
stop_words = set(stopwords.words('english'))

positive_words = [word for word in positive_tokens if word.isalpha() and word not in stop_words]
negative_words = [word for word in negative_tokens if word.isalpha() and word not in stop_words]

# Calculate word frequencies
positive_freq_dist = nltk.FreqDist(positive_words)
negative_freq_dist = nltk.FreqDist(negative_words)
